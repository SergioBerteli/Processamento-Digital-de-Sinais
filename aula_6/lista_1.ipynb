# %% [markdown]
# # Questão 5
# ## A

# %%
from numpy import real, imag, roots
import matplotlib.pyplot as plt

numerador = [1, 0, 0] # z²

denominador = [1, -1/4, 1/2] # z^2 -1/4 z + 1/2


zeros = roots(numerador)
polos = roots(denominador)

print(f"Zeros do sistema: {zeros}")
print(f"Polos do sistema: {polos}")

# plot do gráfico

plt.figure()
plt.scatter(real(zeros), imag(zeros), marker='o', color='blue', label='Zeros')
plt.scatter(real(polos), imag(polos), marker='x', color='red', label='Polos')
plt.axhline(0, color='black', lw=0.5)
plt.axvline(0, color='black', lw=0.5)
plt.grid(True, which='both', linestyle='--', lw=0.5)
plt.xlabel('Real')
plt.ylabel('Imaginário')
plt.title('Polos e zeros da função de transferência')
plt.legend()
plt.show()
# Out:
# Zeros do sistema: [0. 0.]
# Polos do sistema: [0.125+0.69597055j 0.125-0.69597055j]

# %% [markdown]
# # Questão 5
# ## B

# %%
numerador = [1, 0, 0] # z²

denominador = [1, -1/4, 1/2] # z^2 -1/4 z + 1/2


zeros = roots(numerador)
polos = roots(denominador)

print(f"Zeros do sistema: {zeros}")
print(f"Polos do sistema: {polos}")

# plot do gráfico

plt.figure()
plt.scatter(real(zeros), imag(zeros), marker='o', color='blue', label='Zeros')
plt.scatter(real(polos), imag(polos), marker='x', color='red', label='Polos')
plt.axhline(0, color='black', lw=0.5)
plt.axvline(0, color='black', lw=0.5)
plt.grid(True, which='both', linestyle='--', lw=0.5)
plt.xlabel('Real')
plt.ylabel('Imaginário')
plt.title('Polos e zeros da função de transferência')
plt.legend()
plt.show()
