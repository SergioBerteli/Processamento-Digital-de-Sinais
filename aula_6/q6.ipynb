# %% [markdown]
# ## A

# %%
from numpy import real, imag, pi, linspace, roots, cos, sin
import matplotlib.pyplot as plt

numerador = [ 1, 0.6] 

denominador = [1, -0.4, -0.4, -0.2] 

zeros = roots(numerador)
polos = roots(denominador)

# plot do gráfico

theta = linspace(0, 2*pi, 100)
x = cos(theta)
y = sin(theta)

plt.plot(x, y, 'b--', label='Unit Circle')



plt.scatter(real(zeros), imag(zeros), marker='o', color='blue', label='Zeros')
plt.scatter(real(polos), imag(polos), marker='x', color='red', label='Polos')
plt.axhline(0, color='black', lw=0.5)
plt.axvline(0, color='black', lw=0.5)
plt.grid(True, which='both', linestyle='--', lw=0.5)
plt.xlabel('Real')
plt.ylabel('Imaginário')
plt.title('Polos e zeros da função de transferência')
plt.legend()
plt.show()

# %% [markdown]
# ## B

# %%
numerador = [ 1, 0.8] 

denominador = [1, 1, 0.41] 

zeros = roots(numerador)
polos = roots(denominador)

# plot do gráfico

theta = linspace(0, 2*pi, 100)
x = cos(theta)
y = sin(theta)

plt.plot(x, y, 'b--', label='Unit Circle')



plt.scatter(real(zeros), imag(zeros), marker='o', color='blue', label='Zeros')
plt.scatter(real(polos), imag(polos), marker='x', color='red', label='Polos')
plt.axhline(0, color='black', lw=0.5)
plt.axvline(0, color='black', lw=0.5)
plt.grid(True, which='both', linestyle='--', lw=0.5)
plt.xlabel('Real')
plt.ylabel('Imaginário')
plt.title('Polos e zeros da função de transferência')
plt.legend()
plt.show()
